# %%
# !python export.py --weights weight/tiny/exp18.pt \
        --grid --end2end --simplify \
        --topk-all 100 --iou-thres 0.65 --conf-thres 0.35 \
        --img-size 480 480 --max-wh 640
# Out:
# Import onnx_graphsurgeon failure: No module named 'onnx_graphsurgeon'
# Namespace(batch_size=1, conf_thres=0.35, device='cpu', dynamic=False, dynamic_batch=False, end2end=True, fp16=False, grid=True, img_size=[480, 480], include_nms=False, int8=False, iou_thres=0.65, max_wh=640, simplify=True, topk_all=100, weights='weight/tiny/exp18.pt')
# Fusing layers...
# IDetect.fuse
#
# Starting TorchScript export with torch 1.12.1+cu116...
# TorchScript export success, saved as weight/tiny/exp18.torchscript.pt
# CoreML export failure: No module named 'coremltools'
#
# Starting TorchScript-Lite export with torch 1.12.1+cu116...
# TorchScript-Lite export success, saved as weight/tiny/exp18.torchscript.ptl
#
# Starting ONNX export with onnx 1.13.0...
# onnxruntime
#
# Starting to simplify ONNX...
# ONNX export success, saved as weight/tiny/exp18.onnx
#
# Export complete (9.31s). Visualize with https://github.com/lutzroeder/netron.
# YOLOR  v0.1-119-g45f2c1f torch 1.12.1+cu116 CPU
#
# Model Summary: 208 layers, 6010302 parameters, 0 gradients
# C:\Users\marti\AppData\Roaming\Python\Python38\site-packages\torch\functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:2895.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# E:\yolo\yolov7_cnn_deploy\models\yolo.py:150: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if self.grid[i].shape[2:4] != x[i].shape[2:4]:
# C:\Users\marti\AppData\Roaming\Python\Python38\site-packages\torch\onnx\symbolic_opset9.py:4189: UserWarning: Exporting aten::index operator of advanced indexing in opset 12 is achieved by combination of multiple ONNX operators, including Reshape, Transpose, Concat, and Gather. If indices include negative values, the exported graph will produce incorrect results.
#   warnings.warn(

# %%
import os
import cv2
import time
import requests
import argparse
import random
import numpy as np
import onnxruntime as ort
from PIL import Image

names = ['person', 'fall']


class ONNX_engine():
    def __init__(self, weights, size, cuda) -> None:
        self.img_new_shape = (size, size)
        self.weights = weights
        self.device = cuda
        self.init_engine()
        self.names = names
        self.colors = {name: [random.randint(0, 255) for _ in range(3)] for i, name in enumerate(self.names)}

    def init_engine(self):
        providers = ['CUDAExecutionProvider', 'CPUExecutionProvider'] if self.device else ['CPUExecutionProvider']
        self.session = ort.InferenceSession(self.weights, providers=providers)

    def predict(self, im):
        outname = [i.name for i in self.session.get_outputs()]
        inname = [i.name for i in self.session.get_inputs()]
        inp = {inname[0]: im}
        outputs = self.session.run(outname, inp)[0]
        # print(outputs.shape)
        return outputs

    def preprocess(self, img):

        self.img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        image = self.img.copy()
        im, ratio, dwdh = self.letterbox(image, auto=False)
        t1 = time.time()
        outputs = self.predict(im)
        print("預測時間", (time.time() - t1) * 1000, ' ms')
        ori_images = [self.img.copy()]
        for i, (batch_id, x0, y0, x1, y1, cls_id, score) in enumerate(outputs):
            image = ori_images[int(batch_id)]
            box = np.array([x0, y0, x1, y1])
            box -= np.array(dwdh * 2)
            box /= ratio
            box = box.round().astype(np.int32).tolist()
            cls_id = int(cls_id)
            score = round(float(score), 3)
            name = self.names[cls_id]
            color = self.colors[name]
            name += ' ' + str(score)
            print("pre result is :", box, name)
            cv2.rectangle(image, box[:2], box[2:], color, 2)
            cv2.putText(image, name, (box[0], box[1] - 2), cv2.FONT_HERSHEY_SIMPLEX, 0.75, [225, 255, 255], thickness=3)
        a = Image.fromarray(ori_images[0])
        return image

    def letterbox(self, im, color=(114, 114, 114), auto=True, scaleup=True, stride=32):
        # 调整大小和垫图像，同时满足跨步多约束
        shape = im.shape[:2]  # current shape [height, width]
        new_shape = self.img_new_shape

        # 如果是单个size的话，就在这里变成一双
        if isinstance(new_shape, int):
            new_shape = (new_shape, new_shape)

        # 尺度比 (new / old)
        r = min(new_shape[0] / shape[0], new_shape[1] / shape[1])
        if not scaleup:  # 只缩小，不扩大(为了更好的val mAP)
            r = min(r, 1.0)

        # 计算填充
        new_unpad = int(round(shape[1] * r)), int(round(shape[0] * r))
        dw, dh = new_shape[1] - new_unpad[0], new_shape[0] - new_unpad[1]  # wh padding

        if auto:  # 最小矩形区域
            dw, dh = np.mod(dw, stride), np.mod(dh, stride)  # wh padding

        dw /= 2  # divide padding into 2 sides
        dh /= 2

        if shape[::-1] != new_unpad:  # resize
            im = cv2.resize(im, new_unpad, interpolation=cv2.INTER_LINEAR)
        top, bottom = int(round(dh - 0.1)), int(round(dh + 0.1))
        left, right = int(round(dw - 0.1)), int(round(dw + 0.1))
        im = cv2.copyMakeBorder(im, top, bottom, left, right, cv2.BORDER_CONSTANT, value=color)  # add border
        im = im.transpose((2, 0, 1))
        im = np.expand_dims(im, 0)
        im = np.ascontiguousarray(im)
        im = im.astype(np.float32)
        im /= 255
        return im, r, (dw, dh)

if __name__ == '__main__':

    weights = "./weight/tiny/sim.onnx"
    cuda = True
    src = './data_test/outset3.mp4'
    size = 480

    onnx_engine = ONNX_engine(weights, size, cuda)
    video = cv2.VideoCapture(src)
    while video.isOpened():

        ret, image = video.read()

        start = time.time()
        a = onnx_engine.preprocess(image)
        print(f'FPS: {1/ (time.time() -start)} ')
        cv2.imshow('video', a)

        if cv2.waitKey(1)& 0xFF == ord('q'):
            break
# Out:
# 預測時間 461.1215591430664  ms
# pre result is : [1397, 623, 1544, 1014] person 0.944
# pre result is : [956, 1076, 1437, 1199] fall 0.89
# pre result is : [2597, 593, 2660, 741] person 0.725
# pre result is : [1942, 1107, 2191, 1296] fall 0.694
# pre result is : [927, 863, 1208, 994] fall 0.57
# pre result is : [1980, 509, 2029, 613] person 0.52
# pre result is : [2023, 509, 2068, 618] person 0.376
# FPS: 1.995181277670193
# 預測時間 12.024164199829102  ms
# pre result is : [1397, 623, 1544, 1014] person 0.944
# pre result is : [956, 1076, 1436, 1199] fall 0.889
# pre result is : [2597, 593, 2660, 741] person 0.727
# pre result is : [1942, 1107, 2191, 1296] fall 0.698
# pre result is : [927, 863, 1208, 994] fall 0.572
# pre result is : [1980, 509, 2029, 613] person 0.516
# pre result is : [2024, 509, 2068, 619] person 0.376
# FPS: 17.188291171661454
# 預測時間 12.088298797607422  ms
# pre result is : [1395, 622, 1542, 1013] person 0.939
# pre result is : [954, 1075, 1437, 1198] fall 0.888
# pre result is : [2597, 593, 2660, 741] person 0.727
# pre result is : [1942, 1107, 2191, 1295] fall 0.699
# pre result is : [927, 864, 1202, 996] fall 0.528
# pre result is : [1980, 509, 2029, 613] person 0.518
# pre result is : [2024, 509, 2068, 619] person 0.375
# FPS: 16.16289662507418
# 預測時間 12.068748474121094  ms
# pre result is : [1396, 623, 1540, 1013] person 0.941
# pre result is : [955, 1075, 1436, 1198] fall 0.892
# pre result is : [2597, 593, 2659, 741] person 0.728
# pre result is : [1942, 1106, 2191, 1296] fall 0.696
# pre result is : [926, 863, 1209, 994] fall 0.544
# pre result is : [1980, 509, 2029, 613] person 0.518
# pre result is : [2024, 509, 2068, 619] person 0.378
# FPS: 13.192248778846123
# 預測時間 10.04791259765625  ms
# pre result is : [1396, 623, 1540, 1013] person 0.941
# pre result is : [955, 1075, 1436, 1198] fall 0.892
# pre result is : [2597, 593, 2659, 741] person 0.728
# pre result is : [1942, 1106, 2191, 1296] fall 0.695
# pre result is : [926, 863, 1209, 994] fall 0.543
# pre result is : [1980, 509, 2029, 613] person 0.518
# pre result is : [2024, 509, 2068, 619] person 0.378
# FPS: 19.124477922267413
# 預測時間 11.358022689819336  ms
# pre result is : [1396, 623, 1540, 1011] person 0.935
# pre result is : [956, 1075, 1437, 1198] fall 0.888
# pre result is : [2596, 594, 2659, 741] person 0.723
# pre result is : [1942, 1107, 2191, 1296] fall 0.708
# pre result is : [926, 863, 1208, 994] fall 0.533
# pre result is : [1980, 509, 2029, 613] person 0.518
# pre result is : [2024, 509, 2068, 619] person 0.376
# FPS: 18.56346705378324
# 預測時間 9.569168090820312  ms
# pre result is : [1396, 623, 1540, 1011] person 0.935
# pre result is : [956, 1075, 1437, 1198] fall 0.888
# pre result is : [2596, 594, 2659, 741] person 0.723
# pre result is : [1942, 1107, 2191, 1296] fall 0.707
# pre result is : [926, 863, 1208, 994] fall 0.533
# pre result is : [1980, 509, 2029, 613] person 0.518
# pre result is : [2024, 509, 2068, 619] person 0.376
# FPS: 18.558374556427705
# 預測時間 10.628461837768555  ms
# pre result is : [1396, 623, 1540, 1012] person 0.927
# pre result is : [954, 1075, 1432, 1198] fall 0.88
# pre result is : [1943, 1108, 2191, 1296] fall 0.706
# pre result is : [2597, 593, 2658, 741] person 0.67
# pre result is : [929, 861, 1197, 994] fall 0.667
# pre result is : [1981, 509, 2029, 611] person 0.53
# FPS: 16.42171863498974
# 預測時間 12.577056884765625  ms
# pre result is : [1396, 623, 1540, 1012] person 0.926
# pre result is : [954, 1075, 1432, 1198] fall 0.878
# pre result is : [1943, 1108, 2191, 1296] fall 0.706
# pre result is : [929, 861, 1195, 994] fall 0.679
# pre result is : [2597, 593, 2659, 742] person 0.67
# pre result is : [1982, 509, 2030, 611] person 0.525
# FPS: 18.30542620096103
# 預測時間 9.040594100952148  ms
# pre result is : [1398, 624, 1542, 1009] person 0.927
# pre result is : [954, 1075, 1432, 1198] fall 0.873
# pre result is : [1943, 1108, 2191, 1296] fall 0.704
# pre result is : [2597, 593, 2659, 741] person 0.672
# pre result is : [928, 860, 1199, 994] fall 0.665
# pre result is : [1982, 509, 2029, 611] person 0.524
# FPS: 19.324671495180702
# 預測時間 9.792327880859375  ms
# pre result is : [1398, 624, 1542, 1009] person 0.927
# pre result is : [954, 1075, 1432, 1198] fall 0.873
# pre result is : [1943, 1108, 2191, 1296] fall 0.704
# pre result is : [2596, 592, 2658, 741] person 0.672
# pre result is : [928, 860, 1199, 994] fall 0.665
# pre result is : [1982, 509, 2029, 611] person 0.525
# FPS: 19.434629499203023
# 預測時間 12.653350830078125  ms
# pre result is : [1398, 624, 1542, 1010] person 0.927
# pre result is : [954, 1075, 1432, 1198] fall 0.869
# pre result is : [1943, 1109, 2189, 1296] fall 0.683
# pre result is : [2596, 592, 2658, 741] person 0.676
# pre result is : [928, 862, 1194, 999] fall 0.661
# pre result is : [1982, 509, 2029, 611] person 0.511
# FPS: 17.735275587221718
# 預測時間 14.031410217285156  ms
# pre result is : [1398, 624, 1542, 1010] person 0.927
# pre result is : [954, 1075, 1432, 1198] fall 0.869
# pre result is : [1943, 1109, 2189, 1296] fall 0.683
# pre result is : [2596, 592, 2658, 741] person 0.675
# pre result is : [928, 862, 1194, 999] fall 0.66
# pre result is : [1982, 509, 2029, 611] person 0.51
# FPS: 13.958029112062137
# 預測時間 14.574527740478516  ms
# pre result is : [1399, 623, 1545, 1010] person 0.927
# pre result is : [954, 1075, 1432, 1198] fall 0.861
# pre result is : [2596, 592, 2658, 741] person 0.674
# pre result is : [1943, 1108, 2188, 1295] fall 0.66
# pre result is : [927, 863, 1193, 999] fall 0.646
# pre result is : [1981, 509, 2029, 611] person 0.518
# FPS: 14.405148935147183
# 預測時間 22.327423095703125  ms
# pre result is : [1399, 623, 1545, 1010] person 0.927
# pre result is : [955, 1075, 1432, 1198] fall 0.862
# pre result is : [2596, 592, 2658, 741] person 0.675
# pre result is : [1943, 1108, 2189, 1295] fall 0.663
# pre result is : [927, 863, 1193, 999] fall 0.645
# pre result is : [1981, 509, 2029, 611] person 0.518
# FPS: 13.401060121476247
# 預測時間 11.304378509521484  ms
# pre result is : [1401, 623, 1545, 1009] person 0.925
# pre result is : [955, 1076, 1432, 1198] fall 0.858
# pre result is : [2596, 593, 2660, 742] person 0.677
# pre result is : [1943, 1109, 2187, 1294] fall 0.648
# pre result is : [927, 861, 1192, 995] fall 0.636
# pre result is : [1981, 509, 2029, 611] person 0.51
# FPS: 18.29672218393111
# 預測時間 12.087345123291016  ms
# pre result is : [1401, 623, 1545, 1009] person 0.925
# pre result is : [955, 1076, 1432, 1198] fall 0.861
# pre result is : [2596, 593, 2660, 742] person 0.677
# pre result is : [1943, 1109, 2187, 1294] fall 0.651
# pre result is : [927, 861, 1193, 995] fall 0.631
# pre result is : [1981, 509, 2029, 611] person 0.51
# FPS: 15.539523993005128
# 預測時間 10.03718376159668  ms
# pre result is : [1403, 624, 1547, 1010] person 0.934
# pre result is : [955, 1076, 1432, 1198] fall 0.867
# pre result is : [2596, 592, 2659, 741] person 0.682
# pre result is : [1943, 1108, 2187, 1296] fall 0.665
# pre result is : [927, 862, 1192, 1000] fall 0.648
# pre result is : [1981, 509, 2029, 611] person 0.514
# FPS: 17.309804051042473
# 預測時間 13.160467147827148  ms
# pre result is : [1402, 624, 1547, 1010] person 0.934
# pre result is : [955, 1076, 1432, 1198] fall 0.867
# pre result is : [2596, 592, 2659, 741] person 0.678
# pre result is : [1943, 1108, 2187, 1296] fall 0.664
# pre result is : [927, 862, 1192, 1000] fall 0.647
# pre result is : [1981, 509, 2029, 611] person 0.512
# FPS: 16.658540557071422
# 預測時間 11.553764343261719  ms
# pre result is : [1402, 623, 1549, 1009] person 0.931
# pre result is : [955, 1075, 1431, 1198] fall 0.863
# pre result is : [929, 862, 1186, 999] fall 0.689
# pre result is : [2596, 593, 2659, 742] person 0.663
# pre result is : [1943, 1109, 2186, 1295] fall 0.647
# pre result is : [1982, 509, 2029, 611] person 0.508
# FPS: 17.795321959974036
# 預測時間 9.524106979370117  ms
# pre result is : [1402, 623, 1549, 1009] person 0.932
# pre result is : [955, 1075, 1431, 1198] fall 0.863
# pre result is : [929, 862, 1186, 999] fall 0.689
# pre result is : [2597, 593, 2658, 742] person 0.661
# pre result is : [1943, 1109, 2186, 1295] fall 0.646
# pre result is : [1982, 509, 2029, 611] person 0.508
# FPS: 18.328063413824143
# 預測時間 190.89055061340332  ms
# pre result is : [1404, 622, 1550, 1010] person 0.931
# pre result is : [955, 1076, 1431, 1198] fall 0.864
# pre result is : [928, 860, 1186, 1000] fall 0.699
# pre result is : [2596, 591, 2659, 741] person 0.681
# pre result is : [1943, 1109, 2187, 1294] fall 0.649
# pre result is : [1982, 509, 2029, 611] person 0.509
# FPS: 4.351100248557
# 預測時間 12.125968933105469  ms
# pre result is : [1404, 622, 1550, 1010] person 0.931
# pre result is : [955, 1076, 1430, 1198] fall 0.864
# pre result is : [928, 860, 1186, 1000] fall 0.699
# pre result is : [2596, 591, 2659, 741] person 0.68
# pre result is : [1943, 1109, 2187, 1294] fall 0.649
# pre result is : [1982, 509, 2029, 611] person 0.512
# FPS: 17.2092366775533
# 預測時間 27.15325355529785  ms
# pre result is : [1406, 622, 1550, 1009] person 0.93
# pre result is : [954, 1075, 1431, 1198] fall 0.862
# pre result is : [929, 861, 1184, 999] fall 0.717
# pre result is : [2597, 591, 2659, 741] person 0.672
# pre result is : [1943, 1109, 2185, 1294] fall 0.637
# pre result is : [1981, 509, 2029, 611] person 0.508
# FPS: 12.26652160816071
# 預測時間 9.975910186767578  ms
# pre result is : [1406, 622, 1550, 1009] person 0.93
# pre result is : [954, 1075, 1431, 1198] fall 0.862
# pre result is : [929, 861, 1184, 999] fall 0.717
# pre result is : [2597, 592, 2660, 741] person 0.674
# pre result is : [1943, 1109, 2186, 1294] fall 0.639
# pre result is : [1981, 509, 2029, 611] person 0.512
# FPS: 19.713039554820273
# 預測時間 15.203237533569336  ms
# pre result is : [1406, 619, 1553, 1010] person 0.919
# pre result is : [953, 1075, 1430, 1198] fall 0.862
# pre result is : [930, 857, 1184, 999] fall 0.722
# pre result is : [2597, 591, 2659, 741] person 0.673
# pre result is : [1942, 1111, 2188, 1295] fall 0.635
# pre result is : [1981, 509, 2029, 611] person 0.513
# FPS: 12.062996836353179
# 預測時間 26.822805404663086  ms
# pre result is : [1406, 619, 1554, 1010] person 0.919
# pre result is : [954, 1075, 1430, 1198] fall 0.863
# pre result is : [930, 857, 1184, 999] fall 0.724
# pre result is : [2597, 590, 2659, 741] person 0.677
# pre result is : [1942, 1111, 2188, 1295] fall 0.635
# pre result is : [1981, 509, 2029, 611] person 0.514
# FPS: 9.556683155345226
# 預測時間 22.4916934967041  ms
# pre result is : [1408, 618, 1555, 1008] person 0.917
# pre result is : [953, 1075, 1430, 1198] fall 0.863
# pre result is : [930, 854, 1183, 1000] fall 0.721
# pre result is : [2597, 590, 2659, 741] person 0.68
# pre result is : [1941, 1110, 2187, 1296] fall 0.667
# pre result is : [1981, 509, 2029, 611] person 0.513
# FPS: 9.548024630934359
# 預測時間 28.986454010009766  ms
# pre result is : [1408, 618, 1555, 1008] person 0.917
# pre result is : [953, 1075, 1430, 1198] fall 0.863
# pre result is : [930, 854, 1183, 1000] fall 0.719
# pre result is : [2597, 590, 2659, 741] person 0.677
# pre result is : [1941, 1110, 2188, 1296] fall 0.667
# pre result is : [1981, 509, 2029, 611] person 0.513
# FPS: 9.933200868677634
# 預測時間 11.570215225219727  ms
# pre result is : [1407, 619, 1557, 1005] person 0.914
# pre result is : [953, 1074, 1431, 1198] fall 0.867
# pre result is : [930, 854, 1185, 999] fall 0.727
# pre result is : [1941, 1108, 2187, 1297] fall 0.682
# pre result is : [2597, 592, 2659, 741] person 0.673
# pre result is : [1981, 509, 2029, 611] person 0.501
# FPS: 17.405484363588076
# 預測時間 13.245820999145508  ms
# pre result is : [1407, 619, 1557, 1006] person 0.915
# pre result is : [957, 1075, 1431, 1198] fall 0.866
# pre result is : [929, 853, 1185, 994] fall 0.732
# pre result is : [1942, 1109, 2186, 1298] fall 0.693
# pre result is : [2596, 590, 2660, 740] person 0.691
# pre result is : [1981, 509, 2028, 611] person 0.496
# FPS: 16.774733339465758
# 預測時間 10.837793350219727  ms
# pre result is : [1404, 619, 1560, 1006] person 0.911
# pre result is : [956, 1076, 1432, 1197] fall 0.863
# pre result is : [930, 855, 1185, 998] fall 0.76
# pre result is : [2596, 589, 2661, 740] person 0.695
# pre result is : [1942, 1109, 2188, 1299] fall 0.66
# pre result is : [1981, 509, 2028, 611] person 0.506
# FPS: 22.73705209519163
# 預測時間 9.079933166503906  ms
# pre result is : [1404, 619, 1560, 1006] person 0.911
# pre result is : [956, 1076, 1432, 1197] fall 0.864
# pre result is : [930, 855, 1185, 998] fall 0.76
# pre result is : [2596, 589, 2661, 740] person 0.694
# pre result is : [1942, 1109, 2188, 1299] fall 0.661
# pre result is : [1981, 509, 2028, 611] person 0.506
# FPS: 22.310839707650246
# 預測時間 10.038375854492188  ms
# pre result is : [1405, 620, 1560, 1004] person 0.913
# pre result is : [956, 1076, 1432, 1197] fall 0.863
# pre result is : [929, 851, 1185, 995] fall 0.74
# pre result is : [2597, 590, 2661, 740] person 0.682
# pre result is : [1942, 1110, 2191, 1299] fall 0.66
# pre result is : [1980, 509, 2028, 611] person 0.499
# FPS: 18.235152948541817
# 預測時間 23.85997772216797  ms
# pre result is : [1405, 620, 1560, 1004] person 0.913
# pre result is : [956, 1076, 1432, 1197] fall 0.863
# pre result is : [929, 851, 1185, 995] fall 0.74
# pre result is : [2597, 590, 2661, 740] person 0.682
# pre result is : [1941, 1110, 2191, 1299] fall 0.66
# pre result is : [1980, 509, 2028, 611] person 0.499
# FPS: 13.889159690579634
# 預測時間 17.577648162841797  ms
# pre result is : [1410, 621, 1563, 1003] person 0.917
# pre result is : [957, 1076, 1432, 1197] fall 0.862
# pre result is : [929, 854, 1185, 994] fall 0.78
# pre result is : [2597, 591, 2661, 741] person 0.688
# pre result is : [1941, 1110, 2193, 1299] fall 0.662
# pre result is : [1980, 509, 2028, 611] person 0.506
# FPS: 11.636073096097453
# 預測時間 25.042295455932617  ms
# pre result is : [1410, 621, 1563, 1003] person 0.917
# pre result is : [957, 1076, 1432, 1197] fall 0.862
# pre result is : [929, 854, 1185, 994] fall 0.78
# pre result is : [2597, 591, 2661, 741] person 0.688
# pre result is : [1941, 1110, 2193, 1299] fall 0.662
# pre result is : [1980, 509, 2028, 611] person 0.506
# FPS: 16.6190030905777
# 預測時間 18.207550048828125  ms
# pre result is : [1412, 623, 1563, 1000] person 0.919
# pre result is : [955, 1075, 1432, 1197] fall 0.869
# pre result is : [928, 851, 1186, 994] fall 0.767
# pre result is : [2597, 590, 2660, 741] person 0.678
# pre result is : [1941, 1112, 2192, 1299] fall 0.652
# pre result is : [1980, 509, 2028, 611] person 0.491
# FPS: 20.703410829754677
# 預測時間 9.046077728271484  ms
# pre result is : [1412, 623, 1563, 1000] person 0.919
# pre result is : [955, 1075, 1432, 1197] fall 0.869
# pre result is : [928, 851, 1186, 994] fall 0.767
# pre result is : [2597, 590, 2660, 741] person 0.679
# pre result is : [1940, 1112, 2192, 1299] fall 0.654
# pre result is : [1980, 509, 2028, 611] person 0.489
# FPS: 20.97162485812429
# 預測時間 9.54890251159668  ms
# pre result is : [1415, 622, 1565, 998] person 0.919
# pre result is : [957, 1074, 1432, 1197] fall 0.877
# pre result is : [928, 853, 1191, 994] fall 0.761
# pre result is : [2597, 590, 2660, 741] person 0.676
# pre result is : [1941, 1112, 2191, 1297] fall 0.622
# pre result is : [1980, 509, 2028, 611] person 0.495
# FPS: 22.66897267381529
# 預測時間 10.80942153930664  ms
# pre result is : [1415, 622, 1565, 998] person 0.919
# pre result is : [957, 1074, 1432, 1197] fall 0.878
# pre result is : [928, 853, 1191, 994] fall 0.762
# pre result is : [2597, 590, 2660, 741] person 0.676
# pre result is : [1941, 1112, 2191, 1297] fall 0.621
# pre result is : [1980, 509, 2028, 611] person 0.494
# FPS: 20.50633381735334
# 預測時間 10.029792785644531  ms
# pre result is : [1415, 622, 1566, 998] person 0.929
# pre result is : [957, 1074, 1432, 1197] fall 0.879
# pre result is : [927, 853, 1187, 994] fall 0.742
# pre result is : [2596, 589, 2659, 740] person 0.69
# pre result is : [1941, 1113, 2191, 1298] fall 0.612
# pre result is : [1980, 509, 2028, 611] person 0.492
# FPS: 17.233419069610736
# 預測時間 9.522199630737305  ms
# pre result is : [1415, 622, 1566, 998] person 0.93
# pre result is : [957, 1074, 1432, 1197] fall 0.88
# pre result is : [927, 853, 1187, 994] fall 0.742
# pre result is : [2596, 589, 2659, 740] person 0.69
# pre result is : [1941, 1113, 2191, 1298] fall 0.611
# pre result is : [1980, 509, 2028, 611] person 0.492
# FPS: 20.298817198056412
# 預測時間 10.021448135375977  ms
# pre result is : [1418, 624, 1566, 998] person 0.936
# pre result is : [957, 1073, 1431, 1197] fall 0.888
# pre result is : [929, 856, 1187, 997] fall 0.712
# pre result is : [2596, 590, 2660, 741] person 0.7
# pre result is : [1940, 1115, 2192, 1300] fall 0.601
# pre result is : [1980, 509, 2028, 611] person 0.492
# FPS: 22.912306961143674
# 預測時間 19.0885066986084  ms
# pre result is : [1419, 624, 1566, 998] person 0.937
# pre result is : [957, 1073, 1431, 1197] fall 0.887
# pre result is : [929, 856, 1187, 997] fall 0.712
# pre result is : [2596, 590, 2660, 741] person 0.7
# pre result is : [1940, 1115, 2192, 1300] fall 0.601
# pre result is : [1980, 509, 2028, 611] person 0.492
# FPS: 15.606015731390599
# 預測時間 14.03951644897461  ms
# pre result is : [1421, 625, 1570, 997] person 0.954
# pre result is : [956, 1073, 1430, 1197] fall 0.878
# pre result is : [930, 851, 1190, 998] fall 0.708
# pre result is : [2597, 590, 2660, 741] person 0.696
# pre result is : [1940, 1115, 2192, 1301] fall 0.622
# pre result is : [1980, 509, 2028, 611] person 0.492
# FPS: 18.999039698501566
# 預測時間 9.752988815307617  ms
# pre result is : [1421, 625, 1570, 997] person 0.954
# pre result is : [956, 1073, 1430, 1197] fall 0.878
# pre result is : [930, 851, 1190, 998] fall 0.709
# pre result is : [2597, 590, 2660, 741] person 0.696
# pre result is : [1940, 1115, 2192, 1301] fall 0.621
# pre result is : [1980, 509, 2028, 611] person 0.492
# FPS: 19.894529638044464
# 預測時間 10.014533996582031  ms
# pre result is : [1422, 626, 1572, 999] person 0.949
# pre result is : [955, 1073, 1431, 1197] fall 0.887
# pre result is : [2597, 591, 2660, 741] person 0.692
# pre result is : [931, 858, 1187, 997] fall 0.687
# pre result is : [1941, 1113, 2193, 1300] fall 0.638
# pre result is : [1980, 509, 2028, 611] person 0.491
# FPS: 21.431219661744418
# 預測時間 8.75234603881836  ms
# pre result is : [1422, 626, 1572, 999] person 0.949
# pre result is : [955, 1073, 1431, 1197] fall 0.887
# pre result is : [2597, 591, 2660, 741] person 0.692
# pre result is : [931, 858, 1187, 997] fall 0.687
# pre result is : [1941, 1113, 2193, 1300] fall 0.639
# pre result is : [1980, 509, 2028, 611] person 0.491
# FPS: 21.279973211703645
# 預測時間 11.516094207763672  ms
# pre result is : [1423, 627, 1571, 998] person 0.951
# pre result is : [956, 1074, 1430, 1197] fall 0.881
# pre result is : [2596, 591, 2660, 741] person 0.7
# pre result is : [926, 859, 1193, 998] fall 0.653
# pre result is : [1940, 1115, 2193, 1301] fall 0.634
# pre result is : [1980, 509, 2028, 611] person 0.494
# FPS: 20.541886445002767
# 預測時間 11.03663444519043  ms
# pre result is : [1423, 627, 1571, 998] person 0.951
# pre result is : [956, 1074, 1430, 1197] fall 0.882
# pre result is : [2596, 591, 2660, 741] person 0.7
# pre result is : [927, 859, 1193, 998] fall 0.655
# pre result is : [1940, 1115, 2193, 1301] fall 0.634
# pre result is : [1980, 509, 2028, 611] person 0.494
# FPS: 20.647559786942868
# 預測時間 9.033441543579102  ms
# pre result is : [1425, 625, 1571, 999] person 0.95
# pre result is : [955, 1073, 1432, 1197] fall 0.895
# pre result is : [2597, 590, 2661, 741] person 0.708
# pre result is : [929, 858, 1186, 999] fall 0.683
# pre result is : [1940, 1116, 2192, 1301] fall 0.645
# pre result is : [1980, 509, 2028, 611] person 0.481
# FPS: 19.66331936279336
# 預測時間 11.021137237548828  ms
# pre result is : [1425, 625, 1571, 999] person 0.95
# pre result is : [955, 1073, 1432, 1197] fall 0.895
# pre result is : [2597, 590, 2661, 741] person 0.707
# pre result is : [929, 858, 1186, 999] fall 0.684
# pre result is : [1940, 1116, 2192, 1301] fall 0.646
# pre result is : [1980, 509, 2028, 611] person 0.48
# FPS: 18.88960246438753
# 預測時間 10.034799575805664  ms
# pre result is : [1428, 626, 1571, 998] person 0.947
# pre result is : [956, 1074, 1431, 1197] fall 0.883
# pre result is : [2597, 590, 2660, 741] person 0.701
# pre result is : [925, 859, 1185, 996] fall 0.677
# pre result is : [1940, 1116, 2192, 1301] fall 0.637
# pre result is : [1980, 509, 2028, 611] person 0.495
# FPS: 19.67235751003715
# 預測時間 11.026620864868164  ms
# pre result is : [1428, 626, 1571, 998] person 0.947
# pre result is : [956, 1074, 1432, 1197] fall 0.883
# pre result is : [2597, 590, 2660, 741] person 0.701
# pre result is : [925, 858, 1184, 996] fall 0.682
# pre result is : [1940, 1116, 2192, 1301] fall 0.636
# pre result is : [1980, 509, 2028, 611] person 0.495
# FPS: 20.372764452734142
# 預測時間 14.570474624633789  ms
# pre result is : [1428, 626, 1571, 996] person 0.944
# pre result is : [956, 1074, 1433, 1197] fall 0.901
# pre result is : [2596, 591, 2660, 741] person 0.69
# pre result is : [928, 858, 1184, 1000] fall 0.685
# pre result is : [1940, 1116, 2193, 1303] fall 0.654
# pre result is : [1980, 509, 2028, 611] person 0.485
# FPS: 17.772248657856043
# 預測時間 16.27826690673828  ms
# pre result is : [1428, 626, 1571, 996] person 0.944
# pre result is : [956, 1074, 1433, 1197] fall 0.9
# pre result is : [2596, 591, 2660, 741] person 0.69
# pre result is : [928, 858, 1184, 1000] fall 0.686
# pre result is : [1940, 1116, 2193, 1303] fall 0.653
# pre result is : [1980, 509, 2028, 611] person 0.484
# FPS: 17.41733800641164
# 預測時間 47.119140625  ms
# pre result is : [1428, 626, 1571, 996] person 0.944
# pre result is : [956, 1074, 1433, 1197] fall 0.9
# pre result is : [2596, 591, 2660, 741] person 0.689
# pre result is : [928, 858, 1184, 1000] fall 0.686
# pre result is : [1940, 1116, 2193, 1303] fall 0.653
# pre result is : [1980, 509, 2028, 611] person 0.484
# FPS: 11.321850343221014
# 預測時間 29.0830135345459  ms
# pre result is : [1428, 626, 1571, 996] person 0.944
# pre result is : [956, 1074, 1433, 1197] fall 0.9
# pre result is : [2596, 591, 2660, 741] person 0.69
# pre result is : [928, 858, 1184, 1000] fall 0.685
# pre result is : [1940, 1116, 2193, 1303] fall 0.653
# pre result is : [1980, 509, 2028, 611] person 0.484
# FPS: 14.55142936441854
# 預測時間 29.284238815307617  ms
# pre result is : [1426, 626, 1570, 996] person 0.944
# pre result is : [956, 1075, 1433, 1197] fall 0.9
# pre result is : [2596, 591, 2659, 741] person 0.691
# pre result is : [930, 859, 1188, 1000] fall 0.671
# pre result is : [1940, 1116, 2192, 1300] fall 0.636
# pre result is : [1980, 509, 2028, 611] person 0.493
# FPS: 15.909209528144439
# 預測時間 29.352188110351562  ms
# pre result is : [1427, 626, 1570, 996] person 0.944
# pre result is : [956, 1075, 1435, 1197] fall 0.903
# pre result is : [927, 859, 1200, 996] fall 0.684
# pre result is : [2597, 592, 2660, 741] person 0.681
# pre result is : [1940, 1114, 2192, 1299] fall 0.642
# pre result is : [1980, 509, 2028, 611] person 0.524
# FPS: 15.63387915000205
# 預測時間 27.884960174560547  ms
# pre result is : [1427, 624, 1567, 996] person 0.945
# pre result is : [956, 1074, 1434, 1197] fall 0.89
# pre result is : [929, 859, 1187, 999] fall 0.746
# pre result is : [2598, 591, 2660, 741] person 0.674
# pre result is : [1940, 1116, 2192, 1303] fall 0.661
# pre result is : [1980, 509, 2028, 611] person 0.522
# pre result is : [2024, 508, 2068, 618] person 0.35
# FPS: 14.309414393668014
# 預測時間 46.79751396179199  ms
# pre result is : [1427, 624, 1567, 996] person 0.945
# pre result is : [956, 1074, 1434, 1198] fall 0.89
# pre result is : [929, 859, 1187, 999] fall 0.745
# pre result is : [2598, 591, 2660, 741] person 0.674
# pre result is : [1940, 1116, 2192, 1303] fall 0.661
# pre result is : [1980, 509, 2028, 611] person 0.522
# FPS: 11.920750094500766
# 預測時間 19.82569694519043  ms
# pre result is : [1430, 623, 1568, 995] person 0.943
# pre result is : [955, 1075, 1435, 1197] fall 0.9
# pre result is : [928, 859, 1187, 999] fall 0.757
# pre result is : [2598, 592, 2660, 741] person 0.665
# pre result is : [1940, 1114, 2192, 1300] fall 0.651
# pre result is : [1980, 509, 2028, 611] person 0.522
# FPS: 15.610023335181788
# 預測時間 25.183916091918945  ms
# pre result is : [1430, 623, 1568, 995] person 0.943
# pre result is : [955, 1075, 1435, 1197] fall 0.9
# pre result is : [928, 859, 1187, 999] fall 0.761
# pre result is : [2598, 592, 2660, 741] person 0.665
# pre result is : [1940, 1114, 2192, 1300] fall 0.651
# pre result is : [1980, 509, 2028, 611] person 0.522
# FPS: 15.548279952550415
# 預測時間 19.557714462280273  ms
# pre result is : [1428, 621, 1565, 995] person 0.943
# pre result is : [955, 1075, 1435, 1197] fall 0.901
# pre result is : [929, 859, 1191, 999] fall 0.744
# pre result is : [2599, 592, 2660, 741] person 0.668
# pre result is : [1940, 1114, 2192, 1300] fall 0.651
# pre result is : [1980, 509, 2028, 611] person 0.521
# FPS: 17.521311037124608
# 預測時間 34.586191177368164  ms
# pre result is : [1428, 621, 1565, 995] person 0.943
# pre result is : [955, 1075, 1435, 1197] fall 0.902
# pre result is : [929, 859, 1191, 999] fall 0.743
# pre result is : [2599, 592, 2660, 741] person 0.668
# pre result is : [1940, 1114, 2192, 1300] fall 0.651
# pre result is : [1980, 509, 2028, 611] person 0.52
# FPS: 12.719378208802238
# 預測時間 29.108047485351562  ms
# pre result is : [1429, 621, 1564, 996] person 0.942
# pre result is : [957, 1074, 1433, 1197] fall 0.907
# pre result is : [929, 860, 1198, 998] fall 0.749
# pre result is : [2599, 592, 2660, 741] person 0.663
# pre result is : [1940, 1113, 2193, 1301] fall 0.652
# pre result is : [1980, 509, 2028, 611] person 0.508
# pre result is : [2024, 508, 2068, 618] person 0.351
# FPS: 14.7799692018197
# 預測時間 39.482831954956055  ms
# pre result is : [1429, 621, 1564, 996] person 0.942
# pre result is : [957, 1074, 1434, 1197] fall 0.907
# pre result is : [929, 860, 1198, 998] fall 0.746
# pre result is : [2599, 592, 2660, 741] person 0.663
# pre result is : [1940, 1113, 2193, 1300] fall 0.652
# pre result is : [1980, 509, 2028, 611] person 0.508
# pre result is : [2024, 508, 2068, 618] person 0.351
# FPS: 12.196218690208257
# 預測時間 25.94161033630371  ms
# pre result is : [1433, 621, 1563, 994] person 0.943
# pre result is : [956, 1076, 1436, 1197] fall 0.908
# pre result is : [930, 860, 1195, 999] fall 0.77
# pre result is : [2598, 591, 2659, 741] person 0.67
# pre result is : [1940, 1113, 2192, 1300] fall 0.66
# pre result is : [1980, 509, 2028, 611] person 0.519
# FPS: 15.864679627808458
# 預測時間 32.193899154663086  ms
# pre result is : [1433, 621, 1563, 994] person 0.943
# pre result is : [956, 1076, 1436, 1197] fall 0.908
# pre result is : [930, 860, 1195, 999] fall 0.769
# pre result is : [2599, 591, 2659, 741] person 0.669
# pre result is : [1940, 1113, 2192, 1300] fall 0.66
# pre result is : [1980, 509, 2028, 611] person 0.52
# FPS: 14.322314077807485
# 預測時間 32.613515853881836  ms
# pre result is : [1434, 619, 1560, 994] person 0.941
# pre result is : [957, 1076, 1434, 1197] fall 0.912
# pre result is : [930, 860, 1199, 998] fall 0.742
# pre result is : [2599, 591, 2660, 741] person 0.668
# pre result is : [1940, 1116, 2192, 1302] fall 0.655
# pre result is : [1980, 509, 2028, 611] person 0.508
# FPS: 14.541087555686525
# 預測時間 31.815767288208008  ms
# pre result is : [1434, 619, 1560, 994] person 0.94
# pre result is : [957, 1076, 1434, 1197] fall 0.912
# pre result is : [930, 860, 1199, 998] fall 0.742
# pre result is : [2599, 591, 2660, 741] person 0.668
# pre result is : [1940, 1116, 2192, 1302] fall 0.655
# pre result is : [1980, 509, 2028, 611] person 0.508
# FPS: 15.04699243399929
# 預測時間 17.37523078918457  ms
# pre result is : [1435, 620, 1560, 989] person 0.945
# pre result is : [956, 1077, 1439, 1197] fall 0.914
# pre result is : [932, 861, 1196, 999] fall 0.756
# pre result is : [2598, 589, 2658, 740] person 0.667
# pre result is : [1940, 1113, 2192, 1300] fall 0.655
# pre result is : [1980, 509, 2028, 611] person 0.528
# FPS: 20.650914551586617
# 預測時間 19.04439926147461  ms
# pre result is : [1435, 620, 1560, 989] person 0.945
# pre result is : [956, 1077, 1439, 1197] fall 0.914
# pre result is : [932, 861, 1196, 999] fall 0.757
# pre result is : [2598, 589, 2658, 740] person 0.668
# pre result is : [1940, 1113, 2192, 1300] fall 0.656
# pre result is : [1980, 509, 2028, 611] person 0.527
# FPS: 16.0871419585462
# 預測時間 18.762588500976562  ms
# pre result is : [1436, 620, 1558, 990] person 0.942
# pre result is : [957, 1076, 1437, 1198] fall 0.916
# pre result is : [926, 860, 1217, 995] fall 0.661
# pre result is : [1940, 1113, 2192, 1301] fall 0.659
# pre result is : [2599, 592, 2657, 741] person 0.652
# pre result is : [1980, 509, 2028, 611] person 0.515
# FPS: 19.833756555210357
# 預測時間 20.071983337402344  ms
# pre result is : [1436, 620, 1558, 990] person 0.942
# pre result is : [957, 1076, 1437, 1198] fall 0.916
# pre result is : [926, 860, 1217, 995] fall 0.661
# pre result is : [1940, 1113, 2192, 1301] fall 0.659
# pre result is : [2599, 592, 2657, 741] person 0.652
# pre result is : [1980, 509, 2028, 611] person 0.516
# FPS: 14.298097475004006
# 預測時間 17.066001892089844  ms
# pre result is : [1438, 619, 1558, 991] person 0.939
# pre result is : [956, 1076, 1438, 1197] fall 0.915
# pre result is : [2600, 592, 2658, 740] person 0.659
# pre result is : [930, 859, 1196, 1000] fall 0.653
# pre result is : [1940, 1113, 2192, 1299] fall 0.651
# pre result is : [1980, 509, 2028, 611] person 0.516
# FPS: 19.643059861562527
# 預測時間 31.08358383178711  ms
# pre result is : [1438, 619, 1558, 991] person 0.939
# pre result is : [956, 1076, 1438, 1198] fall 0.916
# pre result is : [2600, 592, 2658, 740] person 0.658
# pre result is : [930, 859, 1196, 1000] fall 0.651
# pre result is : [1940, 1113, 2192, 1299] fall 0.65
# pre result is : [1980, 509, 2028, 611] person 0.516
# FPS: 15.585834788748096
# 預測時間 32.80973434448242  ms
# pre result is : [1442, 620, 1558, 991] person 0.934
# pre result is : [956, 1076, 1437, 1198] fall 0.912
# pre result is : [931, 859, 1196, 1000] fall 0.664
# pre result is : [1940, 1113, 2193, 1301] fall 0.66
# pre result is : [2598, 590, 2658, 741] person 0.643
# pre result is : [1980, 509, 2028, 611] person 0.516
# FPS: 15.49365928979613
# 預測時間 33.33544731140137  ms
# pre result is : [1442, 620, 1558, 991] person 0.934
# pre result is : [956, 1076, 1437, 1198] fall 0.912
# pre result is : [931, 859, 1196, 1000] fall 0.664
# pre result is : [1940, 1113, 2193, 1301] fall 0.66
# pre result is : [2598, 590, 2658, 741] person 0.643
# pre result is : [1980, 509, 2028, 611] person 0.517
# FPS: 15.174541613001258
# 預測時間 19.147157669067383  ms
# pre result is : [1442, 620, 1559, 993] person 0.939
# pre result is : [956, 1076, 1437, 1198] fall 0.912
# pre result is : [930, 859, 1195, 1000] fall 0.67
# pre result is : [1940, 1113, 2193, 1300] fall 0.659
# pre result is : [2598, 591, 2659, 741] person 0.639
# pre result is : [1980, 509, 2028, 611] person 0.516
# FPS: 22.878936975660846
# 預測時間 19.061565399169922  ms
# pre result is : [1442, 620, 1559, 993] person 0.939
# pre result is : [956, 1076, 1437, 1198] fall 0.912
# pre result is : [930, 859, 1195, 1000] fall 0.674
# pre result is : [1940, 1113, 2193, 1300] fall 0.66
# pre result is : [2598, 591, 2659, 741] person 0.639
# pre result is : [1980, 509, 2028, 611] person 0.516
# FPS: 17.49492792311799
# 預測時間 19.664764404296875  ms
# pre result is : [1442, 620, 1560, 993] person 0.927
# pre result is : [957, 1075, 1437, 1198] fall 0.913
# pre result is : [931, 858, 1196, 999] fall 0.67
# pre result is : [1940, 1113, 2193, 1300] fall 0.658
# pre result is : [2599, 591, 2659, 741] person 0.636
# pre result is : [1980, 509, 2028, 611] person 0.522
# pre result is : [2024, 508, 2068, 618] person 0.354
# FPS: 19.377345763996047
# 預測時間 19.182443618774414  ms
# pre result is : [1442, 620, 1560, 993] person 0.927
# pre result is : [957, 1075, 1437, 1198] fall 0.914
# pre result is : [931, 858, 1197, 999] fall 0.667
# pre result is : [1940, 1113, 2193, 1300] fall 0.659
# pre result is : [2599, 591, 2659, 741] person 0.636
# pre result is : [1980, 509, 2028, 611] person 0.521
# pre result is : [2024, 508, 2068, 618] person 0.355
# FPS: 18.845214453240835
# 預測時間 20.06220817565918  ms
# pre result is : [1442, 620, 1559, 994] person 0.926
# pre result is : [958, 1076, 1437, 1198] fall 0.915
# pre result is : [1940, 1113, 2193, 1300] fall 0.659
# pre result is : [2599, 590, 2659, 741] person 0.647
# pre result is : [928, 858, 1227, 996] fall 0.642
# pre result is : [1980, 509, 2028, 611] person 0.522
# pre result is : [2024, 508, 2068, 618] person 0.355
# FPS: 18.087082515793785
# 預測時間 19.553661346435547  ms
# pre result is : [1442, 621, 1559, 994] person 0.926
# pre result is : [958, 1076, 1437, 1198] fall 0.915
# pre result is : [1940, 1113, 2193, 1300] fall 0.659
# pre result is : [2599, 590, 2659, 741] person 0.646
# pre result is : [928, 858, 1227, 996] fall 0.642
# pre result is : [1980, 509, 2028, 611] person 0.522
# pre result is : [2024, 508, 2068, 618] person 0.356
# FPS: 15.38866589863442
# 預測時間 19.775390625  ms
# pre result is : [1445, 622, 1562, 994] person 0.924
# pre result is : [958, 1076, 1439, 1198] fall 0.915
# pre result is : [1940, 1113, 2193, 1300] fall 0.658
# pre result is : [929, 859, 1197, 999] fall 0.641
# pre result is : [2600, 591, 2659, 741] person 0.614
# pre result is : [1980, 509, 2028, 611] person 0.524
# pre result is : [2024, 508, 2068, 618] person 0.352
# FPS: 18.98416290616782
# 預測時間 25.508403778076172  ms
# pre result is : [1445, 622, 1562, 994] person 0.924
# pre result is : [958, 1076, 1439, 1198] fall 0.915
# pre result is : [1940, 1113, 2193, 1300] fall 0.658
# pre result is : [930, 859, 1197, 999] fall 0.641
# pre result is : [2600, 591, 2659, 741] person 0.613
# pre result is : [1980, 509, 2028, 611] person 0.524
# pre result is : [2024, 508, 2068, 618] person 0.35
# FPS: 17.992269976020626
# 預測時間 18.41449737548828  ms
# pre result is : [1445, 622, 1564, 993] person 0.926
# pre result is : [958, 1076, 1438, 1198] fall 0.918
# pre result is : [1940, 1113, 2193, 1300] fall 0.659
# pre result is : [929, 858, 1225, 996] fall 0.644
# pre result is : [2601, 589, 2658, 740] person 0.587
# pre result is : [1980, 509, 2028, 611] person 0.527
# FPS: 21.06134664343425
# 預測時間 19.060611724853516  ms
# pre result is : [1445, 622, 1564, 993] person 0.926
# pre result is : [957, 1075, 1439, 1198] fall 0.92
# pre result is : [929, 858, 1222, 996] fall 0.669
# pre result is : [1939, 1113, 2193, 1301] fall 0.658
# pre result is : [2600, 589, 2657, 740] person 0.607
# pre result is : [1980, 509, 2028, 611] person 0.522
# pre result is : [2025, 508, 2068, 617] person 0.359
# FPS: 20.766348477046776
# 預測時間 36.626338958740234  ms
# pre result is : [1445, 623, 1566, 994] person 0.928
# pre result is : [958, 1075, 1439, 1197] fall 0.918
# pre result is : [929, 858, 1223, 997] fall 0.671
# pre result is : [1939, 1114, 2193, 1300] fall 0.651
# pre result is : [2601, 589, 2657, 739] person 0.61
# pre result is : [1980, 509, 2028, 611] person 0.523
# pre result is : [2024, 508, 2068, 617] person 0.354
# FPS: 13.258806161705248
# 預測時間 36.06534004211426  ms
# pre result is : [1445, 623, 1566, 994] person 0.928
# pre result is : [957, 1075, 1439, 1197] fall 0.918
# pre result is : [929, 858, 1223, 997] fall 0.673
# pre result is : [1939, 1114, 2193, 1300] fall 0.651
# pre result is : [2601, 589, 2658, 739] person 0.61
# pre result is : [1980, 509, 2028, 611] person 0.524
# pre result is : [2025, 508, 2068, 617] person 0.354
# FPS: 13.84208494081073
# 預測時間 43.20025444030762  ms
# pre result is : [1445, 624, 1566, 994] person 0.928
# pre result is : [959, 1076, 1439, 1198] fall 0.92
# pre result is : [929, 858, 1231, 996] fall 0.679
# pre result is : [1939, 1114, 2192, 1300] fall 0.651
# pre result is : [2600, 588, 2658, 740] person 0.596
# pre result is : [1980, 509, 2028, 611] person 0.523
# pre result is : [2025, 508, 2068, 617] person 0.357
# FPS: 11.63594397174729
# 預測時間 31.28957748413086  ms
# pre result is : [1445, 624, 1566, 994] person 0.928
# pre result is : [959, 1076, 1439, 1198] fall 0.92
# pre result is : [929, 858, 1231, 996] fall 0.679
# pre result is : [1939, 1114, 2192, 1300] fall 0.651
# pre result is : [2600, 588, 2658, 740] person 0.595
# pre result is : [1980, 509, 2028, 611] person 0.523
# pre result is : [2025, 508, 2068, 617] person 0.358
# FPS: 13.888101931412185
# 預測時間 39.124250411987305  ms
# pre result is : [1447, 624, 1567, 996] person 0.929
# pre result is : [958, 1076, 1439, 1198] fall 0.923
# pre result is : [929, 858, 1231, 996] fall 0.673
# pre result is : [1939, 1114, 2192, 1300] fall 0.654
# pre result is : [2601, 588, 2659, 740] person 0.59
# pre result is : [1980, 509, 2028, 611] person 0.523
# pre result is : [2025, 508, 2068, 617] person 0.358
# FPS: 14.049010544368075
# 預測時間 40.038347244262695  ms
# pre result is : [1447, 624, 1567, 996] person 0.929
# pre result is : [958, 1077, 1439, 1198] fall 0.923
# pre result is : [929, 858, 1231, 996] fall 0.672
# pre result is : [1939, 1114, 2192, 1300] fall 0.653
# pre result is : [2601, 588, 2659, 740] person 0.59
# pre result is : [1980, 509, 2028, 611] person 0.523
# pre result is : [2025, 508, 2068, 617] person 0.358
# FPS: 14.302875713131161
# 預測時間 18.18704605102539  ms
# pre result is : [1448, 624, 1568, 997] person 0.929
# pre result is : [958, 1076, 1438, 1198] fall 0.921
# pre result is : [930, 859, 1227, 996] fall 0.68
# pre result is : [1939, 1114, 2192, 1300] fall 0.651
# pre result is : [2600, 589, 2659, 741] person 0.577
# pre result is : [1980, 509, 2028, 611] person 0.523
# pre result is : [2025, 508, 2068, 617] person 0.359
# FPS: 20.780546775136497
# 預測時間 19.072771072387695  ms
# pre result is : [1448, 624, 1568, 997] person 0.929
# pre result is : [958, 1076, 1438, 1198] fall 0.921
# pre result is : [930, 858, 1227, 996] fall 0.68
# pre result is : [1939, 1114, 2192, 1300] fall 0.651
# pre result is : [2600, 589, 2659, 741] person 0.577
# pre result is : [1980, 509, 2028, 611] person 0.522
# pre result is : [2025, 508, 2068, 617] person 0.36
# FPS: 18.280454319610186
# 預測時間 20.05600929260254  ms
# pre result is : [1447, 623, 1569, 998] person 0.929
# pre result is : [958, 1075, 1439, 1198] fall 0.926
# pre result is : [929, 858, 1227, 996] fall 0.701
# pre result is : [1939, 1113, 2192, 1300] fall 0.652
# pre result is : [2603, 591, 2662, 742] person 0.588
# pre result is : [1980, 509, 2028, 611] person 0.523
# pre result is : [2024, 508, 2068, 617] person 0.361
# FPS: 18.348027314444195
# 預測時間 19.550323486328125  ms
# pre result is : [1447, 623, 1569, 998] person 0.929
# pre result is : [958, 1075, 1439, 1198] fall 0.927
# pre result is : [929, 858, 1227, 996] fall 0.701
# pre result is : [1939, 1113, 2192, 1300] fall 0.653
# pre result is : [2603, 591, 2662, 742] person 0.586
# pre result is : [1980, 509, 2028, 611] person 0.523
# pre result is : [2024, 508, 2068, 617] person 0.361
# FPS: 20.264002357681548
# 預測時間 19.147634506225586  ms
# pre result is : [1448, 623, 1570, 999] person 0.93
# pre result is : [959, 1076, 1440, 1198] fall 0.925
# pre result is : [929, 858, 1237, 995] fall 0.695
# pre result is : [1939, 1113, 2192, 1300] fall 0.651
# pre result is : [2603, 592, 2662, 742] person 0.601
# pre result is : [1980, 509, 2028, 611] person 0.523
# pre result is : [2024, 508, 2068, 617] person 0.361
# FPS: 17.658665970587865
# 預測時間 21.054744720458984  ms
# pre result is : [1448, 623, 1570, 999] person 0.93
# pre result is : [959, 1076, 1440, 1198] fall 0.925
# pre result is : [929, 858, 1237, 995] fall 0.695
# pre result is : [1939, 1113, 2192, 1300] fall 0.651
# pre result is : [2603, 592, 2662, 742] person 0.601
# pre result is : [1980, 509, 2028, 611] person 0.523
# pre result is : [2024, 508, 2068, 617] person 0.361
# FPS: 17.333338843453358
# 預測時間 21.246671676635742  ms
# pre result is : [958, 1074, 1441, 1198] fall 0.931
# pre result is : [1450, 623, 1569, 999] person 0.928
# pre result is : [928, 858, 1235, 995] fall 0.691
# pre result is : [1939, 1113, 2192, 1300] fall 0.656
# pre result is : [2602, 591, 2661, 741] person 0.609
# pre result is : [1980, 509, 2028, 611] person 0.519
# pre result is : [2025, 508, 2068, 617] person 0.361
# FPS: 18.522232575392916
# 預測時間 29.08158302307129  ms
# pre result is : [958, 1074, 1441, 1198] fall 0.931
# pre result is : [1450, 623, 1569, 999] person 0.929
# pre result is : [928, 858, 1235, 995] fall 0.69
# pre result is : [1939, 1113, 2192, 1300] fall 0.657
# pre result is : [2602, 591, 2661, 741] person 0.609
# pre result is : [1981, 509, 2028, 611] person 0.518
# pre result is : [2025, 508, 2068, 617] person 0.36
# FPS: 16.089795573900666
# 預測時間 31.805992126464844  ms
# pre result is : [959, 1070, 1441, 1198] fall 0.934
# pre result is : [1452, 623, 1573, 999] person 0.926
# pre result is : [927, 858, 1234, 996] fall 0.687
# pre result is : [1939, 1113, 2193, 1300] fall 0.654
# pre result is : [2603, 592, 2662, 742] person 0.611
# pre result is : [1980, 509, 2028, 611] person 0.526
# pre result is : [2025, 508, 2068, 617] person 0.373
# FPS: 15.650388059701493
# 預測時間 17.54927635192871  ms
# pre result is : [959, 1070, 1442, 1198] fall 0.935
# pre result is : [1452, 623, 1573, 999] person 0.926
# pre result is : [927, 858, 1234, 995] fall 0.686
# pre result is : [1939, 1113, 2193, 1300] fall 0.654
# pre result is : [2603, 592, 2662, 742] person 0.61
# pre result is : [1980, 509, 2028, 611] person 0.526
# pre result is : [2025, 508, 2068, 617] person 0.374
# FPS: 22.007177786639243
# 預測時間 20.059585571289062  ms
# pre result is : [959, 1068, 1441, 1198] fall 0.935
# pre result is : [1451, 623, 1573, 999] person 0.929
# pre result is : [926, 859, 1233, 996] fall 0.686
# pre result is : [1939, 1113, 2192, 1301] fall 0.66
# pre result is : [2603, 594, 2660, 741] person 0.6
# pre result is : [1980, 509, 2028, 611] person 0.525
# pre result is : [2025, 508, 2068, 617] person 0.367
# FPS: 18.881439098942554
# 預測時間 20.076990127563477  ms
# pre result is : [959, 1068, 1441, 1198] fall 0.935
# pre result is : [1451, 623, 1573, 999] person 0.929
# pre result is : [926, 859, 1234, 996] fall 0.687
# pre result is : [1939, 1113, 2192, 1301] fall 0.661
# pre result is : [2603, 594, 2660, 741] person 0.6
# pre result is : [1980, 509, 2028, 611] person 0.525
# pre result is : [2025, 508, 2068, 617] person 0.367
# FPS: 19.35159775216617
# 預測時間 18.044710159301758  ms
# pre result is : [959, 1069, 1442, 1198] fall 0.933
# pre result is : [1451, 622, 1574, 1000] person 0.927
# pre result is : [925, 859, 1232, 996] fall 0.701
# pre result is : [1939, 1113, 2193, 1300] fall 0.652
# pre result is : [2603, 594, 2661, 741] person 0.602
# pre result is : [1980, 509, 2028, 611] person 0.525
# pre result is : [2024, 508, 2068, 617] person 0.367
# FPS: 19.14219603583539
# 預測時間 18.829345703125  ms
# pre result is : [959, 1069, 1442, 1198] fall 0.933
# pre result is : [1451, 622, 1574, 1000] person 0.927
# pre result is : [925, 859, 1232, 996] fall 0.699
# pre result is : [1939, 1113, 2193, 1300] fall 0.652
# pre result is : [2603, 594, 2661, 741] person 0.602
# pre result is : [1980, 509, 2028, 611] person 0.525
# pre result is : [2024, 508, 2068, 617] person 0.367
# FPS: 19.976681272623356
# 預測時間 30.839204788208008  ms
# pre result is : [1452, 623, 1575, 1000] person 0.928
# pre result is : [959, 1074, 1441, 1198] fall 0.926
# pre result is : [925, 859, 1233, 996] fall 0.695
# pre result is : [1939, 1113, 2192, 1300] fall 0.652
# pre result is : [2604, 594, 2661, 741] person 0.606
# pre result is : [1980, 509, 2028, 611] person 0.526
# pre result is : [2024, 508, 2068, 617] person 0.366
# FPS: 14.302339221168928
# 預測時間 47.22785949707031  ms
# pre result is : [1452, 623, 1575, 1000] person 0.928
# pre result is : [958, 1074, 1441, 1198] fall 0.925
# pre result is : [925, 859, 1233, 996] fall 0.695
# pre result is : [1939, 1113, 2192, 1300] fall 0.652
# pre result is : [2604, 594, 2661, 741] person 0.603
# pre result is : [1980, 509, 2028, 611] person 0.526
# pre result is : [2024, 508, 2068, 617] person 0.366
# FPS: 11.602500691562932
# 預測時間 52.310943603515625  ms
# pre result is : [1450, 623, 1575, 1000] person 0.929
# pre result is : [958, 1073, 1442, 1198] fall 0.926
# pre result is : [925, 859, 1232, 996] fall 0.676
# pre result is : [2604, 592, 2662, 742] person 0.651
# pre result is : [1939, 1113, 2192, 1300] fall 0.65
# pre result is : [1980, 509, 2028, 611] person 0.526
# pre result is : [2024, 508, 2068, 617] person 0.366
# FPS: 11.57125989030998
# 預測時間 20.938873291015625  ms
# pre result is : [1450, 623, 1575, 1000] person 0.929
# pre result is : [958, 1073, 1442, 1198] fall 0.926
# pre result is : [925, 859, 1232, 996] fall 0.675
# pre result is : [1939, 1113, 2192, 1300] fall 0.65
# pre result is : [2604, 592, 2662, 742] person 0.648
# pre result is : [1980, 509, 2028, 611] person 0.526
# pre result is : [2024, 508, 2068, 617] person 0.366
# FPS: 16.48114864572814
# 預測時間 20.34735679626465  ms
# pre result is : [1450, 623, 1577, 1001] person 0.928
# pre result is : [960, 1075, 1442, 1198] fall 0.923
# pre result is : [924, 859, 1230, 996] fall 0.671
# pre result is : [1939, 1113, 2192, 1300] fall 0.651
# pre result is : [2604, 592, 2661, 742] person 0.628
# pre result is : [1980, 509, 2028, 611] person 0.525
# pre result is : [2024, 508, 2068, 617] person 0.368
# FPS: 19.077244961543535
# 預測時間 18.273591995239258  ms
# pre result is : [1449, 623, 1578, 1000] person 0.929
# pre result is : [960, 1077, 1442, 1198] fall 0.92
# pre result is : [924, 859, 1229, 996] fall 0.673
# pre result is : [1939, 1113, 2192, 1300] fall 0.648
# pre result is : [2604, 591, 2661, 742] person 0.614
# pre result is : [1981, 509, 2028, 611] person 0.522
# pre result is : [2024, 508, 2068, 617] person 0.371
# FPS: 20.49180680274768
# 預測時間 28.855085372924805  ms
# pre result is : [1449, 624, 1578, 1000] person 0.929
# pre result is : [960, 1077, 1442, 1198] fall 0.92
# pre result is : [924, 859, 1229, 996] fall 0.672
# pre result is : [1939, 1113, 2192, 1300] fall 0.648
# pre result is : [2604, 591, 2661, 742] person 0.614
# pre result is : [1981, 509, 2028, 611] person 0.522
# pre result is : [2024, 508, 2068, 617] person 0.37
# FPS: 17.414228477714808
# 預測時間 36.38458251953125  ms
# pre result is : [1449, 624, 1578, 1000] person 0.929
# pre result is : [960, 1077, 1442, 1198] fall 0.92
# pre result is : [924, 859, 1229, 996] fall 0.672
# pre result is : [1939, 1113, 2192, 1300] fall 0.648
# pre result is : [2604, 591, 2661, 742] person 0.614
# pre result is : [1981, 509, 2028, 611] person 0.522
# pre result is : [2024, 508, 2068, 617] person 0.37
# FPS: 14.319722502936116
# 預測時間 19.048452377319336  ms
# pre result is : [1449, 626, 1580, 998] person 0.927
# pre result is : [960, 1076, 1441, 1198] fall 0.92
# pre result is : [924, 859, 1231, 996] fall 0.68
# pre result is : [1939, 1113, 2192, 1300] fall 0.651
# pre result is : [2603, 590, 2661, 741] person 0.598
# pre result is : [1980, 509, 2028, 611] person 0.527
# pre result is : [2024, 508, 2068, 617] person 0.377
# FPS: 20.693911181500177
# 預測時間 19.38772201538086  ms
# pre result is : [1450, 625, 1579, 998] person 0.926
# pre result is : [960, 1076, 1440, 1199] fall 0.917
# pre result is : [923, 860, 1230, 996] fall 0.663
# pre result is : [1939, 1113, 2193, 1299] fall 0.655
# pre result is : [2604, 590, 2661, 742] person 0.609
# pre result is : [1981, 509, 2029, 611] person 0.522
# pre result is : [2569, 573, 2615, 718] person 0.408
# pre result is : [2025, 508, 2068, 617] person 0.36
# FPS: 20.22247936434467
# 預測時間 19.05059814453125  ms
# pre result is : [1449, 627, 1577, 998] person 0.926
# pre result is : [959, 1076, 1440, 1199] fall 0.917
# pre result is : [924, 859, 1228, 996] fall 0.682
# pre result is : [1939, 1113, 2193, 1300] fall 0.663
# pre result is : [2603, 591, 2662, 742] person 0.597
# pre result is : [1981, 509, 2029, 611] person 0.52
# pre result is : [2024, 508, 2068, 617] person 0.36
# FPS: 14.734278778766472
# 預測時間 22.631168365478516  ms
# pre result is : [1449, 627, 1577, 998] person 0.925
# pre result is : [959, 1076, 1440, 1199] fall 0.917
# pre result is : [924, 859, 1228, 996] fall 0.683
# pre result is : [1939, 1113, 2193, 1300] fall 0.662
# pre result is : [2603, 591, 2661, 742] person 0.595
# pre result is : [1981, 509, 2029, 611] person 0.519
# pre result is : [2024, 508, 2068, 617] person 0.359
# FPS: 15.920018522665593
# 預測時間 33.10370445251465  ms
# pre result is : [1451, 627, 1581, 999] person 0.924
# pre result is : [959, 1076, 1442, 1198] fall 0.917
# pre result is : [923, 860, 1211, 995] fall 0.708
# pre result is : [1939, 1113, 2193, 1299] fall 0.654
# pre result is : [2604, 590, 2661, 742] person 0.593
# pre result is : [1981, 509, 2029, 611] person 0.531
# pre result is : [2569, 573, 2614, 717] person 0.41
# pre result is : [2024, 508, 2068, 617] person 0.363
# FPS: 14.210609412745255
# 預測時間 43.52569580078125  ms
# pre result is : [1451, 627, 1581, 999] person 0.924
# pre result is : [959, 1076, 1442, 1198] fall 0.917
# pre result is : [923, 860, 1211, 995] fall 0.709
# pre result is : [1939, 1113, 2193, 1299] fall 0.654
# pre result is : [2604, 590, 2661, 742] person 0.593
# pre result is : [1981, 509, 2029, 611] person 0.531
# pre result is : [2569, 573, 2614, 717] person 0.41
# pre result is : [2024, 508, 2068, 617] person 0.363
# FPS: 12.31829048382644
# 預測時間 26.59749984741211  ms
# pre result is : [1451, 628, 1580, 999] person 0.922
# pre result is : [958, 1075, 1440, 1198] fall 0.916
# pre result is : [923, 860, 1211, 995] fall 0.717
# ...
# pre result is : [798, 565, 945, 910] person 0.892
# pre result is : [959, 1072, 1432, 1199] fall 0.834
# pre result is : [1783, 812, 1922, 1009] person 0.781
# pre result is : [2600, 600, 2659, 738] person 0.556
# pre result is : [1983, 509, 2030, 612] person 0.534
# FPS: 14.342835257427367
# 預測時間 44.81625556945801  ms
# pre result is : [1901, 779, 2057, 1201] person 0.925
# pre result is : [798, 565, 945, 910] person 0.891
# pre result is : [959, 1072, 1432, 1199] fall 0.834
# pre result is : [1783, 812, 1922, 1009] person 0.78
# pre result is : [2600, 600, 2659, 738] person 0.555
# pre result is : [1983, 509, 2030, 612] person 0.534
# FPS: 15.005112243985332
# 預測時間 49.75533485412598  ms
# pre result is : [1895, 778, 2056, 1199] person 0.936
# pre result is : [794, 560, 943, 911] person 0.896
# pre result is : [959, 1072, 1432, 1199] fall 0.838
# pre result is : [1781, 811, 1922, 1010] person 0.729
# pre result is : [2601, 600, 2660, 739] person 0.581
# pre result is : [1983, 509, 2030, 612] person 0.534
# FPS: 15.042189674217102
# 預測時間 50.68254470825195  ms
# pre result is : [1895, 778, 2056, 1199] person 0.935
# pre result is : [794, 560, 943, 911] person 0.896
# pre result is : [959, 1072, 1432, 1199] fall 0.838
# pre result is : [1781, 811, 1922, 1010] person 0.733
# pre result is : [2601, 600, 2660, 739] person 0.58
# pre result is : [1983, 509, 2030, 612] person 0.534
# FPS: 14.883763182921463
# 預測時間 40.7102108001709  ms
# pre result is : [1880, 782, 2054, 1198] person 0.957
# pre result is : [796, 563, 932, 911] person 0.911
# pre result is : [959, 1072, 1432, 1199] fall 0.841
# pre result is : [1781, 813, 1919, 1012] person 0.675
# pre result is : [2598, 600, 2657, 740] person 0.567
# pre result is : [1983, 509, 2030, 612] person 0.534
# FPS: 16.899568878681656
# 預測時間 19.121170043945312  ms
# pre result is : [1880, 782, 2054, 1198] person 0.957
# pre result is : [796, 563, 932, 912] person 0.911
# pre result is : [959, 1072, 1432, 1199] fall 0.84
# pre result is : [1781, 813, 1919, 1012] person 0.677
# pre result is : [2598, 600, 2657, 740] person 0.567
# pre result is : [1983, 509, 2030, 612] person 0.534
# FPS: 26.204573285018117
# 預測時間 19.22893524169922  ms
# pre result is : [1869, 780, 2047, 1196] person 0.943
# pre result is : [794, 569, 926, 910] person 0.917
# pre result is : [959, 1072, 1432, 1199] fall 0.83
# pre result is : [1782, 815, 1920, 1013] person 0.603
# pre result is : [2597, 601, 2657, 740] person 0.58
# pre result is : [1983, 509, 2030, 612] person 0.532
# FPS: 27.165005407996063
# 預測時間 18.5699462890625  ms
# pre result is : [1868, 780, 2047, 1196] person 0.943
# pre result is : [794, 569, 925, 910] person 0.918
# pre result is : [959, 1072, 1432, 1199] fall 0.83
# pre result is : [1782, 815, 1920, 1013] person 0.602
# pre result is : [2598, 601, 2657, 740] person 0.584
# pre result is : [1983, 509, 2030, 612] person 0.532
# FPS: 25.46478052334406
# 預測時間 17.635107040405273  ms
# pre result is : [1851, 779, 2047, 1193] person 0.933
# pre result is : [793, 569, 922, 910] person 0.924
# pre result is : [959, 1072, 1432, 1199] fall 0.837
# pre result is : [2597, 602, 2657, 740] person 0.571
# pre result is : [1983, 509, 2030, 612] person 0.533
# pre result is : [1786, 818, 1923, 1007] person 0.511
# FPS: 23.346956042549166
# 預測時間 18.297195434570312  ms
# pre result is : [1851, 779, 2047, 1193] person 0.933
# pre result is : [793, 569, 922, 909] person 0.924
# pre result is : [959, 1072, 1432, 1199] fall 0.837
# pre result is : [2597, 602, 2657, 740] person 0.572
# pre result is : [1983, 509, 2030, 612] person 0.533
# pre result is : [1786, 818, 1923, 1007] person 0.511
# FPS: 20.960620477351778
# 預測時間 19.321441650390625  ms
# pre result is : [1849, 777, 2043, 1194] person 0.928
# pre result is : [794, 567, 920, 910] person 0.928
# pre result is : [959, 1072, 1432, 1199] fall 0.834
# pre result is : [1983, 509, 2030, 612] person 0.535
# pre result is : [2597, 601, 2657, 740] person 0.533
# pre result is : [1787, 818, 1925, 1008] person 0.453
# FPS: 20.758948368704466
# 預測時間 18.03135871887207  ms
# pre result is : [1850, 777, 2044, 1193] person 0.931
# pre result is : [794, 567, 920, 910] person 0.928
# pre result is : [958, 1072, 1433, 1199] fall 0.831
# pre result is : [2597, 600, 2658, 739] person 0.54
# pre result is : [1983, 509, 2030, 612] person 0.529
# pre result is : [1787, 818, 1925, 1008] person 0.471
# FPS: 23.333448304636867
# 預測時間 19.10996437072754  ms
# pre result is : [795, 568, 919, 910] person 0.93
# pre result is : [1830, 778, 2042, 1193] person 0.905
# pre result is : [958, 1072, 1433, 1199] fall 0.832
# pre result is : [2598, 600, 2657, 740] person 0.533
# pre result is : [1983, 509, 2030, 612] person 0.532
# pre result is : [1788, 815, 1928, 1013] person 0.415
# FPS: 22.02960177316512
# 預測時間 17.833948135375977  ms
# pre result is : [795, 568, 919, 910] person 0.93
# pre result is : [1830, 778, 2042, 1193] person 0.905
# pre result is : [958, 1072, 1433, 1199] fall 0.831
# pre result is : [2597, 600, 2657, 740] person 0.534
# pre result is : [1983, 509, 2030, 612] person 0.534
# pre result is : [1788, 815, 1928, 1013] person 0.415
# FPS: 20.493508904795643
# 預測時間 20.07436752319336  ms
# pre result is : [793, 569, 915, 908] person 0.929
# pre result is : [1821, 777, 2040, 1196] person 0.905
# pre result is : [958, 1071, 1433, 1199] fall 0.828
# pre result is : [1983, 509, 2030, 612] person 0.534
# pre result is : [2594, 601, 2655, 739] person 0.494
# FPS: 20.546917940754312
# 預測時間 21.555423736572266  ms
# pre result is : [793, 569, 915, 908] person 0.929
# pre result is : [1821, 777, 2040, 1196] person 0.905
# pre result is : [958, 1071, 1433, 1199] fall 0.828
# pre result is : [1983, 509, 2030, 612] person 0.534
# pre result is : [2594, 601, 2655, 739] person 0.493
# FPS: 18.467347657625925
# 預測時間 20.235776901245117  ms
# pre result is : [791, 569, 911, 906] person 0.921
# pre result is : [1822, 778, 2033, 1194] person 0.905
# pre result is : [958, 1071, 1432, 1198] fall 0.833
# pre result is : [1983, 509, 2030, 612] person 0.534
# pre result is : [2593, 602, 2653, 739] person 0.422
# pre result is : [1788, 822, 1905, 1004] person 0.365
# FPS: 19.603307175673844
# 預測時間 19.12236213684082  ms
# pre result is : [791, 569, 911, 906] person 0.921
# pre result is : [1822, 778, 2034, 1194] person 0.905
# pre result is : [958, 1071, 1432, 1198] fall 0.834
# pre result is : [1983, 509, 2030, 612] person 0.534
# pre result is : [2593, 602, 2653, 739] person 0.421
# pre result is : [1788, 822, 1905, 1004] person 0.367
# FPS: 22.36878623198067
# 預測時間 20.23005485534668  ms
# pre result is : [788, 575, 909, 899] person 0.922
# pre result is : [1823, 776, 2031, 1194] person 0.92
# pre result is : [958, 1071, 1432, 1198] fall 0.842
# pre result is : [1983, 509, 2030, 612] person 0.532
# pre result is : [2590, 599, 2650, 739] person 0.432
# FPS: 19.896417101898894
# 預測時間 20.14327049255371  ms
# pre result is : [788, 575, 909, 899] person 0.922
# pre result is : [1823, 776, 2031, 1194] person 0.92
# pre result is : [958, 1071, 1432, 1198] fall 0.841
# pre result is : [1983, 509, 2030, 612] person 0.532
# pre result is : [2591, 599, 2650, 739] person 0.434
# FPS: 19.0234260548528
# 預測時間 19.719839096069336  ms
# pre result is : [1826, 777, 2025, 1193] person 0.918
# pre result is : [787, 568, 899, 902] person 0.915
# pre result is : [957, 1071, 1432, 1198] fall 0.844
# pre result is : [1983, 509, 2030, 612] person 0.539
# pre result is : [1792, 831, 1901, 1003] person 0.411
# FPS: 21.829984125744918
# 預測時間 19.901037216186523  ms
# pre result is : [1826, 777, 2025, 1193] person 0.919
# pre result is : [787, 568, 899, 902] person 0.914
# pre result is : [957, 1071, 1432, 1198] fall 0.844
# pre result is : [1983, 509, 2030, 612] person 0.539
# pre result is : [1792, 831, 1901, 1003] person 0.411
# FPS: 22.21147562687002
# 預測時間 18.577098846435547  ms
# pre result is : [1826, 772, 2020, 1191] person 0.932
# pre result is : [784, 562, 893, 904] person 0.887
# pre result is : [957, 1071, 1432, 1199] fall 0.837
# pre result is : [1982, 509, 2030, 612] person 0.542
# FPS: 22.748767457627117
# 預測時間 34.96694564819336  ms
# pre result is : [1826, 772, 2020, 1191] person 0.933
# pre result is : [784, 562, 893, 904] person 0.888
# pre result is : [957, 1071, 1432, 1199] fall 0.837
# pre result is : [1982, 509, 2030, 612] person 0.542
# FPS: 15.62805393784256
# 預測時間 19.59371566772461  ms
# pre result is : [1832, 776, 2019, 1190] person 0.923
# pre result is : [782, 563, 885, 900] person 0.908
# pre result is : [957, 1071, 1432, 1198] fall 0.847
# pre result is : [1982, 509, 2030, 612] person 0.542
# pre result is : [2593, 589, 2652, 737] person 0.402
# FPS: 16.692019930275872
# 預測時間 21.605968475341797  ms
# pre result is : [1832, 776, 2019, 1190] person 0.923
# pre result is : [782, 563, 885, 900] person 0.908
# pre result is : [957, 1071, 1432, 1198] fall 0.846
# pre result is : [1982, 509, 2030, 612] person 0.542
# pre result is : [2593, 589, 2652, 737] person 0.403
# FPS: 17.014603751541507
# 預測時間 19.72341537475586  ms
# pre result is : [780, 566, 877, 901] person 0.931
# pre result is : [1835, 774, 2014, 1192] person 0.93
# pre result is : [957, 1071, 1432, 1198] fall 0.843
# pre result is : [1982, 509, 2030, 612] person 0.539
# pre result is : [2588, 587, 2649, 735] person 0.351
# FPS: 15.623105919513685
# 預測時間 69.46587562561035  ms
# pre result is : [780, 566, 877, 901] person 0.931
# pre result is : [1835, 774, 2014, 1193] person 0.93
# pre result is : [957, 1071, 1432, 1198] fall 0.843
# pre result is : [1982, 509, 2030, 612] person 0.539
# pre result is : [2588, 587, 2649, 735] person 0.36
# FPS: 8.850572481230296
# 預測時間 67.1541690826416  ms
# pre result is : [1838, 775, 2009, 1195] person 0.926
# pre result is : [778, 568, 872, 900] person 0.92
# pre result is : [957, 1070, 1432, 1198] fall 0.849
# pre result is : [1982, 509, 2030, 612] person 0.539
# pre result is : [2573, 574, 2639, 730] person 0.446
# FPS: 9.145229410007566
# 預測時間 66.13731384277344  ms
# pre result is : [1838, 775, 2009, 1195] person 0.927
# pre result is : [778, 568, 872, 900] person 0.919
# pre result is : [957, 1070, 1432, 1198] fall 0.849
# pre result is : [1982, 509, 2030, 612] person 0.539
# pre result is : [2573, 574, 2639, 730] person 0.445
# FPS: 10.50130192685174
# 預測時間 62.65568733215332  ms
# pre result is : [773, 572, 865, 906] person 0.929
# pre result is : [1831, 773, 2007, 1198] person 0.925
# pre result is : [956, 1070, 1432, 1198] fall 0.851
# pre result is : [1982, 509, 2030, 612] person 0.538
# pre result is : [2565, 567, 2626, 721] person 0.386
# FPS: 10.27177328308023
# 預測時間 63.581228256225586  ms
# pre result is : [773, 572, 865, 906] person 0.929
# pre result is : [1831, 773, 2007, 1198] person 0.925
# pre result is : [957, 1070, 1432, 1199] fall 0.851
# pre result is : [1982, 509, 2030, 612] person 0.538
# pre result is : [2564, 567, 2626, 721] person 0.384
# FPS: 11.087506707799022
# 預測時間 57.6326847076416  ms
# pre result is : [1822, 772, 2001, 1191] person 0.937
# pre result is : [770, 566, 857, 912] person 0.917
# pre result is : [957, 1070, 1432, 1198] fall 0.848
# pre result is : [1982, 509, 2030, 612] person 0.537
# FPS: 12.360254377641171
# 預測時間 58.095455169677734  ms
# pre result is : [1822, 772, 2001, 1191] person 0.937
# pre result is : [770, 566, 857, 912] person 0.918
# pre result is : [957, 1070, 1432, 1198] fall 0.849
# pre result is : [1982, 509, 2030, 612] person 0.537
# FPS: 11.810150248913118
# 預測時間 55.365562438964844  ms
# pre result is : [1819, 772, 1999, 1192] person 0.929
# pre result is : [767, 572, 854, 905] person 0.906
# pre result is : [956, 1070, 1432, 1199] fall 0.853
# pre result is : [1982, 509, 2030, 612] person 0.54
# FPS: 12.128259920365267
# 預測時間 55.43017387390137  ms
# pre result is : [1819, 772, 1999, 1192] person 0.929
# pre result is : [767, 571, 853, 905] person 0.906
# pre result is : [956, 1070, 1432, 1199] fall 0.853
# pre result is : [1982, 509, 2030, 612] person 0.54
# FPS: 12.373417665505329
# 預測時間 73.72546195983887  ms
# pre result is : [1820, 765, 1994, 1187] person 0.91
# pre result is : [765, 561, 858, 897] person 0.888
# pre result is : [956, 1070, 1432, 1199] fall 0.861
# pre result is : [1983, 509, 2030, 612] person 0.542
# FPS: 9.785143710339678
# 預測時間 70.00517845153809  ms
# pre result is : [1820, 764, 1994, 1187] person 0.91
# pre result is : [765, 561, 859, 897] person 0.886
# pre result is : [956, 1070, 1432, 1199] fall 0.861
# pre result is : [1982, 509, 2030, 612] person 0.542
# FPS: 9.548481095650907
# 預測時間 65.60945510864258  ms
# pre result is : [1819, 763, 1993, 1185] person 0.898
# pre result is : [758, 561, 856, 899] person 0.896
# pre result is : [956, 1070, 1432, 1199] fall 0.859
# pre result is : [1983, 509, 2030, 612] person 0.551
# FPS: 9.782587603089897
# 預測時間 69.67663764953613  ms
# pre result is : [1819, 763, 1993, 1185] person 0.899
# pre result is : [758, 561, 856, 899] person 0.897
# pre result is : [956, 1070, 1432, 1199] fall 0.859
# pre result is : [1983, 509, 2030, 612] person 0.551
# FPS: 10.057173549200808
# 預測時間 71.00057601928711  ms
# pre result is : [744, 562, 854, 900] person 0.899
# pre result is : [1821, 762, 1993, 1178] person 0.89
# pre result is : [956, 1070, 1432, 1199] fall 0.854
# pre result is : [1983, 509, 2030, 612] person 0.552
# FPS: 8.344797811489679
# 預測時間 71.57278060913086  ms
# pre result is : [743, 561, 854, 900] person 0.895
# pre result is : [1820, 762, 1993, 1180] person 0.893
# pre result is : [958, 1070, 1431, 1198] fall 0.848
# pre result is : [1983, 509, 2030, 612] person 0.547
# FPS: 9.397631717508935
# 預測時間 70.03140449523926  ms
# pre result is : [732, 558, 852, 899] person 0.902
# pre result is : [1818, 762, 1994, 1177] person 0.899
# pre result is : [958, 1070, 1431, 1198] fall 0.85
# pre result is : [1983, 509, 2030, 612] person 0.546
# FPS: 9.696064062434983
# 預測時間 61.21110916137695  ms
# pre result is : [732, 558, 852, 899] person 0.902
# pre result is : [1818, 762, 1994, 1177] person 0.899
# pre result is : [958, 1070, 1431, 1198] fall 0.85
# pre result is : [1983, 509, 2030, 612] person 0.549
# FPS: 10.714213824267954
# 預測時間 58.489084243774414  ms
# pre result is : [727, 557, 857, 898] person 0.919
# pre result is : [1814, 762, 1994, 1175] person 0.9
# pre result is : [958, 1070, 1431, 1198] fall 0.85
# pre result is : [1983, 509, 2030, 612] person 0.548
# FPS: 11.997368436107346
# 預測時間 70.97887992858887  ms
# pre result is : [727, 557, 857, 898] person 0.919
# pre result is : [1814, 762, 1994, 1175] person 0.9
# pre result is : [958, 1070, 1431, 1198] fall 0.85
# pre result is : [1983, 509, 2030, 612] person 0.548
# FPS: 10.147370560242319
# 預測時間 57.68918991088867  ms
# pre result is : [725, 557, 857, 901] person 0.918
# pre result is : [1815, 762, 1992, 1173] person 0.894
# pre result is : [958, 1070, 1431, 1198] fall 0.85
# pre result is : [1983, 509, 2030, 612] person 0.549
# FPS: 11.596245455425152
# 預測時間 62.747955322265625  ms
# pre result is : [725, 557, 857, 901] person 0.918
# pre result is : [1815, 762, 1992, 1173] person 0.895
# pre result is : [958, 1070, 1431, 1198] fall 0.85
# pre result is : [1983, 509, 2030, 612] person 0.549
# FPS: 10.639203918514779
# 預測時間 70.49155235290527  ms
# pre result is : [720, 558, 855, 900] person 0.926
# pre result is : [1813, 760, 1993, 1169] person 0.902
# pre result is : [958, 1071, 1431, 1198] fall 0.851
# pre result is : [1983, 509, 2030, 612] person 0.55
# FPS: 9.50725005610095
# 預測時間 57.177066802978516  ms
# pre result is : [720, 558, 855, 900] person 0.926
# pre result is : [1813, 760, 1993, 1169] person 0.902
# pre result is : [958, 1071, 1431, 1198] fall 0.851
# pre result is : [1983, 509, 2030, 612] person 0.55
# FPS: 11.363813456229188
# 預測時間 62.19792366027832  ms
# pre result is : [718, 556, 849, 897] person 0.93
# pre result is : [1814, 757, 1990, 1168] person 0.895
# pre result is : [956, 1071, 1434, 1198] fall 0.834
# pre result is : [1982, 508, 2030, 612] person 0.547
# FPS: 11.066210401061689
# 預測時間 57.100772857666016  ms
# pre result is : [718, 556, 849, 897] person 0.929
# pre result is : [1814, 758, 1990, 1168] person 0.895
# pre result is : [956, 1071, 1434, 1198] fall 0.833
# pre result is : [1982, 508, 2030, 612] person 0.547
# FPS: 12.387999220268298
# 預測時間 48.631906509399414  ms
# pre result is : [718, 559, 850, 896] person 0.926
# pre result is : [1813, 757, 1990, 1168] person 0.901
# pre result is : [956, 1071, 1433, 1198] fall 0.832
# pre result is : [1982, 508, 2030, 612] person 0.542
# FPS: 13.94577700343798
